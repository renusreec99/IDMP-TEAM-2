# %%
import pandas as pd

# %%
file_path = '/Users/renuchava/Downloads/Crime_Data_from_2020_to_Present.csv'
file_path2 = '/Users/renuchava/Downloads/Crime_Data_from_2010_to_2019.csv'

# %%
crime_data_2 = pd.read_csv(file_path)
crime_data_1 = pd.read_csv(file_path2)

# %%
crime_data_2.head()
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0  190326475  03/01/2020 12:00:00 AM  03/01/2020 12:00:00 AM      2130     7
# 1  200106753  02/09/2020 12:00:00 AM  02/08/2020 12:00:00 AM      1800     1
# 2  200320258  11/11/2020 12:00:00 AM  11/04/2020 12:00:00 AM      1700     3
# 3  200907217  05/10/2023 12:00:00 AM  03/10/2020 12:00:00 AM      2037     9
# 4  220614831  08/18/2022 12:00:00 AM  08/17/2020 12:00:00 AM      1200     6
#
#    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0   Wilshire          784         1     510
# 1    Central          182         1     330
# 2  Southwest          356         1     480
# 3   Van Nuys          964         1     343
# 4  Hollywood          666         2     354
#
#                                 Crm Cd Desc  ... Status   Status Desc  \
# 0                          VEHICLE - STOLEN  ...     AA  Adult Arrest
# 1                     BURGLARY FROM VEHICLE  ...     IC   Invest Cont
# ...

# %%
crime_data_1.head()
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA   \
# 0    1307355  02/20/2010 12:00:00 AM  02/20/2010 12:00:00 AM      1350     13
# 1   11401303  09/13/2010 12:00:00 AM  09/12/2010 12:00:00 AM        45     14
# 2   70309629  08/09/2010 12:00:00 AM  08/09/2010 12:00:00 AM      1515     13
# 3   90631215  01/05/2010 12:00:00 AM  01/05/2010 12:00:00 AM       150      6
# 4  100100501  01/03/2010 12:00:00 AM  01/02/2010 12:00:00 AM      2100      1
#
#    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0     Newton         1385         2     900
# 1    Pacific         1485         2     740
# 2     Newton         1324         2     946
# 3  Hollywood          646         2     900
# 4    Central          176         1     122
#
#                                          Crm Cd Desc  ... Status  \
# 0                           VIOLATION OF COURT ORDER  ...     AA
# 1  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...  ...     IC
# ...

# %%
import pandas as pd
from datetime import datetime



crime_data2_cleaned = crime_data_2.rename(columns={
    'DR_NO': 'Record_Number',
    'Date Rptd': 'Reported_Crime_Date',
    'DATE OCC': 'Actual_Crime_Date',
    'TIME OCC': 'Actual_Crime_Time',
    'AREA': 'Area',
    'AREA NAME': 'Area_Name',
    'Rpt Dist No': 'Reported_District_Number',
    'Crm Cd': 'Crime_Code',
    'Crm Cd Desc': 'Crime_Code_Desc',
    'Vict Age': 'Victim_Age',
    'Vict Sex': 'Victim_Sex',
    'Vict Descent': 'Victim_Cultural_Group',
    'Premis Cd': 'Premis_Code',
    'Premis Desc': 'Premis_Desc',
    'Weapon Used Cd': 'Weapon_Used_Code',
    'Weapon Desc': 'Weapon_Desc',
    'Status': 'File_Status',
    'Status Desc': 'File_Status_Desc',
    'Crm Cd 1': 'Crime_Code_1',
    'LOCATION': 'Crime_Location',
    'Cross Street': 'Location_Cross_Street',
    'LAT': 'Latitude',
    'LON': 'Longitude'
})

crime_data2_cleaned['Record_Number'] = pd.to_numeric(crime_data2_cleaned['Record_Number'], errors='coerce')
crime_data2_cleaned['Reported_Crime_Date'] = pd.to_datetime(crime_data2_cleaned['Reported_Crime_Date'], format='%m/%d/%Y %I:%M:%S %p', errors='coerce')
crime_data2_cleaned['Actual_Crime_Date'] = pd.to_datetime(crime_data2_cleaned['Actual_Crime_Date'], format='%m/%d/%Y %I:%M:%S %p', errors='coerce')
crime_data2_cleaned['Actual_Crime_Time'] = crime_data2_cleaned['Actual_Crime_Time'].astype(str).str.zfill(4)  # Zero-pad time
crime_data2_cleaned['Actual_Crime_Time'] = pd.to_datetime(crime_data2_cleaned['Actual_Crime_Time'].str[:2] + ':' + crime_data2_cleaned['Actual_Crime_Time'].str[2:], format='%H:%M', errors='coerce')
crime_data2_cleaned['Reported_District_Number'] = pd.to_numeric(crime_data2_cleaned['Reported_District_Number'], errors='coerce')
crime_data2_cleaned['Crime_Code'] = pd.to_numeric(crime_data2_cleaned['Crime_Code'], errors='coerce')
crime_data2_cleaned['Victim_Age'] = pd.to_numeric(crime_data2_cleaned['Victim_Age'], errors='coerce')
crime_data2_cleaned['Premis_Code'] = pd.to_numeric(crime_data2_cleaned['Premis_Code'], errors='coerce')
crime_data2_cleaned['Weapon_Used_Code'] = pd.to_numeric(crime_data2_cleaned['Weapon_Used_Code'], errors='coerce')
crime_data2_cleaned['Crime_Code_1'] = pd.to_numeric(crime_data2_cleaned['Crime_Code_1'], errors='coerce')
crime_data2_cleaned['Latitude'] = pd.to_numeric(crime_data2_cleaned['Latitude'], errors='coerce')
crime_data2_cleaned['Longitude'] = pd.to_numeric(crime_data2_cleaned['Longitude'], errors='coerce')

# %%
import pandas as pd

# Assuming crime_data_1 is your DataFrame containing the raw crime data

# Rename columns similar to crime_data_2
crime_data_1_cleaned = crime_data_1.rename(columns={
    'DR_NO': 'Record_Number',
    'Date Rptd': 'Reported_Crime_Date',
    'DATE OCC': 'Actual_Crime_Date',
    'TIME OCC': 'Actual_Crime_Time',
    'AREA': 'Area',
    'AREA NAME': 'Area_Name',
    'Rpt Dist No': 'Reported_District_Number',
    'Crm Cd': 'Crime_Code',
    'Crm Cd Desc': 'Crime_Code_Desc',
    'Vict Age': 'Victim_Age',
    'Vict Sex': 'Victim_Sex',
    'Vict Descent': 'Victim_Cultural_Group',
    'Premis Cd': 'Premis_Code',
    'Premis Desc': 'Premis_Desc',
    'Weapon Used Cd': 'Weapon_Used_Code',
    'Weapon Desc': 'Weapon_Desc',
    'Status': 'File_Status',
    'Status Desc': 'File_Status_Desc',
    'Crm Cd 1': 'Crime_Code_1',
    'LOCATION': 'Crime_Location',
    'Cross Street': 'Location_Cross_Street',
    'LAT': 'Latitude',
    'LON': 'Longitude'
})

# Convert columns to appropriate data types
crime_data_1_cleaned['Record_Number'] = pd.to_numeric(crime_data_1_cleaned['Record_Number'], errors='coerce')
crime_data_1_cleaned['Reported_Crime_Date'] = pd.to_datetime(crime_data_1_cleaned['Reported_Crime_Date'], format='%m/%d/%Y %I:%M:%S %p', errors='coerce')
crime_data_1_cleaned['Actual_Crime_Date'] = pd.to_datetime(crime_data_1_cleaned['Actual_Crime_Date'], format='%m/%d/%Y %I:%M:%S %p', errors='coerce')
crime_data_1_cleaned['Actual_Crime_Time'] = crime_data_1_cleaned['Actual_Crime_Time'].astype(str).str.zfill(4)  # Zero-pad time
crime_data_1_cleaned['Actual_Crime_Time'] = pd.to_datetime(crime_data_1_cleaned['Actual_Crime_Time'].str[:2] + ':' + crime_data_1_cleaned['Actual_Crime_Time'].str[2:], format='%H:%M', errors='coerce')
crime_data_1_cleaned['Reported_District_Number'] = pd.to_numeric(crime_data_1_cleaned['Reported_District_Number'], errors='coerce')
crime_data_1_cleaned['Crime_Code'] = pd.to_numeric(crime_data_1_cleaned['Crime_Code'], errors='coerce')
crime_data_1_cleaned['Victim_Age'] = pd.to_numeric(crime_data_1_cleaned['Victim_Age'], errors='coerce')
crime_data_1_cleaned['Premis_Code'] = pd.to_numeric(crime_data_1_cleaned['Premis_Code'], errors='coerce')
crime_data_1_cleaned['Weapon_Used_Code'] = pd.to_numeric(crime_data_1_cleaned['Weapon_Used_Code'], errors='coerce')
crime_data_1_cleaned['Crime_Code_1'] = pd.to_numeric(crime_data_1_cleaned['Crime_Code_1'], errors='coerce')
crime_data_1_cleaned['Latitude'] = pd.to_numeric(crime_data_1_cleaned['Latitude'], errors='coerce')
crime_data_1_cleaned['Longitude'] = pd.to_numeric(crime_data_1_cleaned['Longitude'], errors='coerce')

# Now crime_data_1_cleaned should be your cleaned DataFrame

# %%
crime_data2_filtered = crime_data2_cleaned[
    (crime_data2_cleaned['Victim_Age'] != 0) & (~crime_data2_cleaned['Victim_Age'].isna()) &
    (crime_data2_cleaned['Victim_Sex'] != 'unknown') & (~crime_data2_cleaned['Victim_Sex'].isna()) &
    (crime_data2_cleaned['Victim_Cultural_Group'] != 'unknown') & (~crime_data2_cleaned['Victim_Cultural_Group'].isna()) &
    (crime_data2_cleaned['Premis_Code'] != 0) & (~crime_data2_cleaned['Premis_Code'].isna()) &
    (crime_data2_cleaned['Premis_Desc'] != 0) & (~crime_data2_cleaned['Premis_Desc'].isna()) &
    (crime_data2_cleaned['Weapon_Used_Code'] != 0) & (~crime_data2_cleaned['Weapon_Used_Code'].isna()) &
    (crime_data2_cleaned['Weapon_Desc'] != 0) & (~crime_data2_cleaned['Weapon_Desc'].isna()) &
    (crime_data2_cleaned['File_Status'] != 0) & (~crime_data2_cleaned['File_Status'].isna()) &
    (crime_data2_cleaned['Crime_Code_1'] != 0) & (~crime_data2_cleaned['Crime_Code_1'].isna()) &
    (crime_data2_cleaned['Location_Cross_Street'] != 0) & (~crime_data2_cleaned['Location_Cross_Street'].isna()) &
    (~crime_data2_cleaned['Weapon_Used_Code'].isna())
]

# %%
crime_data1_filtered = crime_data_1_cleaned[
    (crime_data_1_cleaned['Victim_Age'] != 0) & (~crime_data_1_cleaned['Victim_Age'].isna()) &
    (crime_data_1_cleaned['Victim_Sex'] != 'unknown') & (~crime_data_1_cleaned['Victim_Sex'].isna()) &
    (crime_data_1_cleaned['Victim_Cultural_Group'] != 'unknown') & (~crime_data_1_cleaned['Victim_Cultural_Group'].isna()) &
    (crime_data_1_cleaned['Premis_Code'] != 0) & (~crime_data_1_cleaned['Premis_Code'].isna()) &
    (crime_data_1_cleaned['Premis_Desc'] != 0) & (~crime_data_1_cleaned['Premis_Desc'].isna()) &
    (crime_data_1_cleaned['Weapon_Used_Code'] != 0) & (~crime_data_1_cleaned['Weapon_Used_Code'].isna()) &
    (crime_data_1_cleaned['Weapon_Desc'] != 0) & (~crime_data_1_cleaned['Weapon_Desc'].isna()) &
    (crime_data_1_cleaned['File_Status'] != 0) & (~crime_data_1_cleaned['File_Status'].isna()) &
    (crime_data_1_cleaned['Crime_Code_1'] != 0) & (~crime_data_1_cleaned['Crime_Code_1'].isna()) &
    (crime_data_1_cleaned['Location_Cross_Street'] != 0) & (~crime_data_1_cleaned['Location_Cross_Street'].isna()) &
    (~crime_data_1_cleaned['Weapon_Used_Code'].isna())
]

# %%
crime_data2_filtered.columns.tolist()
# Out:
# ['Record_Number',
#  'Reported_Crime_Date',
#  'Actual_Crime_Date',
#  'Actual_Crime_Time',
#  'Area',
#  'Area_Name',
#  'Reported_District_Number',
#  'Part 1-2',
#  'Crime_Code',
#  'Crime_Code_Desc',
#  'Mocodes',
#  'Victim_Age',
#  'Victim_Sex',
#  'Victim_Cultural_Group',
#  'Premis_Code',
#  'Premis_Desc',
#  'Weapon_Used_Code',
#  'Weapon_Desc',
#  'File_Status',
#  'File_Status_Desc',
#  'Crime_Code_1',
#  'Crm Cd 2',
#  'Crm Cd 3',
#  'Crm Cd 4',
#  'Crime_Location',
#  'Location_Cross_Street',
#  'Latitude',
#  'Longitude']

# %%
columns_to_exclude = ['Location_Cross_Street', 'Crm Cd 2', 'Crm Cd 3', 'Crm Cd 4', 'Mocodes']

crime_data2_filtered = crime_data2_filtered.drop(columns=columns_to_exclude)
crime_data1_filtered = crime_data1_filtered.drop(columns=columns_to_exclude)

# %%
concatenated_df = pd.concat([crime_data1_filtered, crime_data2_filtered], ignore_index=True)

# Display the head of the concatenated DataFrame
print(concatenated_df.head())

# Calculate the sum of NaN values for each column
null_counts_data_final = concatenated_df.isna().sum()

# Print the count of NaN values for each column
print(null_counts_data_final)
# Out:
#    Record_Number Reported_Crime_Date Actual_Crime_Date   Actual_Crime_Time  \
# 0       90631215          2010-01-05        2010-01-05 1900-01-01 01:50:00
# 1      100100501          2010-01-03        2010-01-02 1900-01-01 21:00:00
# 2      100100522          2010-01-15        2010-01-14 1900-01-01 20:00:00
# 3      100100531          2010-01-16        2010-01-15 1900-01-01 20:30:00
# 4      100100574          2010-02-01        2010-01-31 1900-01-01 19:30:00
#
#    AREA   Area_Name  Reported_District_Number  Part 1-2  Crime_Code  \
# 0    6.0  Hollywood                       646         2         900
# 1    1.0    Central                       176         1         122
# 2    1.0    Central                       158         1         210
# 3    1.0    Central                       127         1         210
# 4    1.0    Central                       145         2         624
#
#             Crime_Code_Desc  ...             Premis_Desc Weapon_Used_Code  \
# ...

# %%
grouped_counts = concatenated_df.groupby(list(concatenated_df.columns)).size().reset_index(name='Count')

duplicate_counts1 = grouped_counts[grouped_counts['Count'] > 1]

print(duplicate_counts1)
# Out:
# Empty DataFrame
# Columns: [Record_Number, Reported_Crime_Date, Actual_Crime_Date, Actual_Crime_Time, AREA , Area_Name, Reported_District_Number, Part 1-2, Crime_Code, Crime_Code_Desc, Victim_Age, Victim_Sex, Victim_Cultural_Group, Premis_Code, Premis_Desc, Weapon_Used_Code, Weapon_Desc, File_Status, File_Status_Desc, Crime_Code_1, Crime_Location, Latitude, Longitude, Area, Count]
# Index: []
#
# [0 rows x 25 columns]

# %%
import pandas as pd
import folium


filtered_data = concatenated_df[['Latitude', 'Longitude', 'Crime_Code_Desc']].dropna()


location_counts = filtered_data.groupby(['Latitude', 'Longitude']).size().reset_index(name='Crime_Count')


high_crime_locations = location_counts[location_counts['Crime_Count'] >= 200]


crime_map = folium.Map(location=[34.052235, -118.243683], zoom_start=10, width='200%', height='200%')

def assign_color_and_size(count):
    if count >= 400:
        return 'red', 3
    elif count >= 300:
        return 'orange', 2.5
    elif count >= 250:
        return 'blue', 2
    elif count >= 50:
        return 'green', 1.5
    else:
        return 'gray', 1  


for index, row in high_crime_locations.iterrows():
    latitude, longitude, count = row['Latitude'], row['Longitude'], row['Crime_Count']
    color, marker_size = assign_color_and_size(count)
    crime_types = '<br>'.join(filtered_data[(filtered_data['Latitude'] == latitude) & (filtered_data['Longitude'] == longitude)]['Crime_Code_Desc'].unique())
    popup_text = f"Latitude: {latitude:.6f}<br>Longitude: {longitude:.6f}<br>Crime Count: {count}<br><br><strong>Crime Types:</strong><br>{crime_types}"
    folium.CircleMarker(
        location=[latitude, longitude],
        radius=marker_size,
        color=color,
        fill=True,
        fill_color=color,
        fill_opacity=0.7,
        popup=popup_text
    ).add_to(crime_map)

crime_map.save('crime_map_filtered.html')

crime_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
concatenated_df = concatenated_df[(concatenated_df['Victim_Sex'] != 'N') & (concatenated_df['Victim_Sex'] != 'X') & (concatenated_df['Victim_Sex'] != 'H')]

# %%
concatenated_df['Crime_Code_1'].dtype
# Out:
# dtype('float64')

# %%
data_subset = concatenated_df[['Victim_Sex', 'Crime_Code_1']]

# %%
data_subset.dropna(inplace=True)
# Out:
# /var/folders/58/chlpf3nd1_l54ygz5xn6hk_00000gn/T/ipykernel_8306/3307635704.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_subset.dropna(inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
le = LabelEncoder()
data_subset['Victim_Sex_Encoded'] = le.fit_transform(data_subset['Victim_Sex'])
# Out:
# /var/folders/58/chlpf3nd1_l54ygz5xn6hk_00000gn/T/ipykernel_8306/3490110481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_subset['Victim_Sex_Encoded'] = le.fit_transform(data_subset['Victim_Sex'])

# %%
# Normalize the data (optional, depending on the scale of 'Crime_Code_1')
scaler = StandardScaler()
data_normalized = scaler.fit_transform(data_subset[['Victim_Sex_Encoded', 'Crime_Code_1']])

# %%
k_values = range(2, 11)  # Testing k from 2 to 10

# Empty list to store inertia values
inertia_values = []

# Loop over each k value to find inertia
for k in k_values:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(data_normalized)
    inertia_values.append(kmeans.inertia_)

# Plotting the Elbow curve
plt.plot(k_values, inertia_values, marker='o')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Inertia')
plt.title('Elbow Method for Optimal k')
plt.show()
# Out:
# /Users/renuchava/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/renuchava/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/renuchava/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
scaler = StandardScaler()
data_normalized = scaler.fit_transform(data_subset[['Victim_Sex_Encoded', 'Crime_Code_1']])

# Initialize and fit K-means clustering model
kmeans = KMeans(n_clusters=4, random_state=42)  # Assuming 4 clusters
kmeans.fit(data_normalized)

# Add cluster labels to the DataFrame
data_subset['Cluster'] = kmeans.labels_

# Display cluster centers
cluster_centers = scaler.inverse_transform(kmeans.cluster_centers_)
print("Cluster Centers:")
print(pd.DataFrame(cluster_centers, columns=['Victim_Sex_Encoded', 'Crime_Code_1']))
# Out:
# /Users/renuchava/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# Cluster Centers:
#    Victim_Sex_Encoded  Crime_Code_1
# 0        1.000000e+00    226.587250
# 1        8.393286e-14    682.506342
# 2        7.460699e-14    230.158726
# 3        1.000000e+00    676.805740
# /var/folders/58/chlpf3nd1_l54ygz5xn6hk_00000gn/T/ipykernel_8306/3518932367.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_subset['Cluster'] = kmeans.labels_

# %%
# Define a function to decode 'Victim_Sex_Encoded' back to original labels
def decode_victim_sex(encoded_sex):
    if encoded_sex == 0:
        return 'F'  # Female
    elif encoded_sex == 1:
        return 'M'  # Male
    else:
        return 'Unknown'

# %%
# Assuming data_subset contains the necessary columns 'Victim_Sex_Encoded' and 'Crime_Code_1'

# Perform k-means clustering with optimal k
optimal_k = 4
kmeans = KMeans(n_clusters=optimal_k, random_state=42)
cluster_labels = kmeans.fit_predict(data_normalized)

# Add cluster labels to the DataFrame
data_subset['Cluster'] = cluster_labels

# Define a new column 'Decoded_Victim_Sex' by applying the decoding function
data_subset['Decoded_Victim_Sex'] = data_subset['Victim_Sex_Encoded'].apply(decode_victim_sex)
# Out:
# /Users/renuchava/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /var/folders/58/chlpf3nd1_l54ygz5xn6hk_00000gn/T/ipykernel_8306/4095971479.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_subset['Cluster'] = cluster_labels
# /var/folders/58/chlpf3nd1_l54ygz5xn6hk_00000gn/T/ipykernel_8306/4095971479.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
import matplotlib.pyplot as plt

# Plotting the clusters with decoded victim sex
plt.figure(figsize=(8, 6))
plt.scatter(data_subset['Decoded_Victim_Sex'], data_subset['Crime_Code_1'], c=cluster_labels, cmap='viridis', alpha=0.5)
plt.xlabel('Victim Sex')
plt.ylabel('Crime Code 1')
plt.title('K-means Clustering of Victim Sex and Crime Code')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import pandas as pd
import folium

# Assuming 'crime_data2_cleaned' is your DataFrame
# Load and preprocess your data if not already done

# Find the most common crime location
max_occurred_location = concatenated_df['Crime_Location'].mode()[0]

# Filter data for the most occurred location
max_occurred_data = crime_data2_cleaned[crime_data2_cleaned['Crime_Location'] == max_occurred_location]

# Get the mean latitude and longitude of the most occurred location
max_lat = max_occurred_data['Latitude'].mean()
max_lon = max_occurred_data['Longitude'].mean()

# Create a map centered around the most occurred location
crime_map = folium.Map(location=[max_lat, max_lon], zoom_start=12)

# Add markers for each crime incident at this location
for index, row in max_occurred_data.iterrows():
    popup_text = f"Crime Location: {row['Crime_Location']}\nCrime Description: {row['Crime_Code_Desc']}"
    folium.Marker([row['Latitude'], row['Longitude']], popup=popup_text).add_to(crime_map)

# Save the map to an HTML file
crime_map.save('crime_map_most_occurred.html')

# Display the map
crime_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
crime_data_1_cleaned.columns.tolist()
# Out:
# ['Record_Number',
#  'Reported_Crime_Date',
#  'Actual_Crime_Date',
#  'Actual_Crime_Time',
#  'AREA ',
#  'Area_Name',
#  'Reported_District_Number',
#  'Part 1-2',
#  'Crime_Code',
#  'Crime_Code_Desc',
#  'Mocodes',
#  'Victim_Age',
#  'Victim_Sex',
#  'Victim_Cultural_Group',
#  'Premis_Code',
#  'Premis_Desc',
#  'Weapon_Used_Code',
#  'Weapon_Desc',
#  'File_Status',
#  'File_Status_Desc',
#  'Crime_Code_1',
#  'Crm Cd 2',
#  'Crm Cd 3',
#  'Crm Cd 4',
#  'Crime_Location',
#  'Location_Cross_Street',
#  'Latitude',
#  'Longitude']

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Example of using concatenated_df (replace with your DataFrame)
# Assuming concatenated_df is your combined DataFrame with the specified columns

# Example: Trend of Reported Crimes Over Time
concatenated_df['Reported_Crime_Date'] = pd.to_datetime(concatenated_df['Reported_Crime_Date'])
concatenated_df['Date'] = concatenated_df['Reported_Crime_Date'].dt.date
crime_trend = concatenated_df.groupby('Date').size().reset_index(name='Count')

plt.figure(figsize=(10, 6))
plt.plot(crime_trend['Date'], crime_trend['Count'], marker='o')
plt.title('Trend of Reported Crimes Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Crimes')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# Modify this example for other line graphs (age distribution, crime types, areas) using concatenated_df.

# %%
# Frequency of Crime Types
plt.figure(figsize=(12, 6))
crime_type_counts = concatenated_df['Crime_Code_Desc'].value_counts().sort_values(ascending=False)
crime_type_counts.plot(kind='bar', color='coral')
plt.title('Frequency of Different Crime Types')
plt.xlabel('Crime Type')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %%
# Crime Rates Across Areas
plt.figure(figsize=(12, 8))
area_crime_counts = concatenated_df['Area_Name'].value_counts().sort_values(ascending=False)
area_crime_counts.plot(kind='line', marker='o', linestyle='-', color='green')
plt.title('Crime Rates Across Areas')
plt.xlabel('Area')
plt.ylabel('Number of Crimes')
plt.grid(True)
plt.xticks(rotation=45)
plt.show()

# %%
area_crime_counts = concatenated_df['Area_Name'].value_counts().sort_index()

# Plotting
plt.figure(figsize=(12, 8))
area_crime_counts.plot(kind='line', marker='o', linestyle='-', color='green')

plt.title('Crime Rates Across Areas')
plt.xlabel('Area')
plt.ylabel('Number of Crimes')
plt.grid(True)
plt.xticks(rotation=45)

# Display all areas on the x-axis
plt.xticks(range(len(area_crime_counts.index)), area_crime_counts.index)

plt.show()

# %%
chosen_k = 4
kmeans = KMeans(n_clusters=chosen_k, random_state=42)
kmeans.fit(data_normalized)

# Step 5: Assign Cluster Labels to DataFrame and Display Cluster Centers
data_subset['Cluster'] = kmeans.labels_
cluster_centers = scaler.inverse_transform(kmeans.cluster_centers_)

# Display Cluster Centers
cluster_centers_df = pd.DataFrame(cluster_centers, columns=['Victim_Sex_Encoded', 'Crime_Code_1'])
print("Cluster Centers:")
print(cluster_centers_df)

# Step 6: Visualize Clustered Data (Optional)
# Example: Scatter plot of 'Crime_Code_1' vs 'Victim_Sex_Encoded' colored by cluster labels
plt.figure(figsize=(8, 6))
plt.scatter(data_subset['Crime_Code_1'], data_subset['Victim_Sex_Encoded'], c=data_subset['Cluster'], cmap='viridis')
plt.xlabel('Crime Code 1')
# Out:
# /Users/renuchava/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# Cluster Centers:
#    Victim_Sex_Encoded  Crime_Code_1
# 0        1.000000e+00    226.587250
# 1        8.393286e-14    682.506342
# 2        7.460699e-14    230.158726
# 3        1.000000e+00    676.805740
# /var/folders/58/chlpf3nd1_l54ygz5xn6hk_00000gn/T/ipykernel_8306/364386068.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_subset['Cluster'] = kmeans.labels_
# Text(0.5, 0, 'Crime Code 1')

# %%
# Perform K-means Clustering with Chosen Number of Clusters (e.g., k=4)
chosen_k = 4
kmeans = KMeans(n_clusters=chosen_k, random_state=42)
kmeans.fit(data_normalized)

# Assign Cluster Labels to DataFrame
data_subset['Cluster'] = kmeans.labels_

# Display the first few rows of the dataframe to see the cluster labels with the original data
print(data_subset.head())
# Out:
# /Users/renuchava/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
#   Victim_Sex  Crime_Code_1  Victim_Sex_Encoded  Cluster Decoded_Victim_Sex
# 0          F         900.0                   0        1                  F
# 1          F         122.0                   0        2                  F
# 2          M         210.0                   1        0                  M
# 3          M         210.0                   1        0                  M
# 4          M         624.0                   1        3                  M
# /var/folders/58/chlpf3nd1_l54ygz5xn6hk_00000gn/T/ipykernel_8306/3274854338.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# Display Cluster Centers after inverse transforming the scaling
cluster_centers = scaler.inverse_transform(kmeans.cluster_centers_)
cluster_centers_df = pd.DataFrame(cluster_centers, columns=['Victim_Sex_Encoded', 'Crime_Code_1'])
print("Cluster Centers:")
print(cluster_centers_df)
# Out:
# Cluster Centers:
#    Victim_Sex_Encoded  Crime_Code_1
# 0        1.000000e+00    226.587250
# 1        8.393286e-14    682.506342
# 2        7.460699e-14    230.158726
# 3        1.000000e+00    676.805740

# %%
cluster_counts = data_subset['Cluster'].value_counts()

# Display the number of records in each cluster
print("Number of records per cluster:")
print(cluster_counts)
# Out:
# Number of records per cluster:
# Cluster
# 0    89776
# 1    61569
# 3    49933
# 2    45544
# Name: count, dtype: int64

# %%
filtered_rows = concatenated_df[concatenated_df['Crime_Code'] == 624]

# Extract Crime_Code_Desc for filtered rows
crime_code_desc = filtered_rows['Crime_Code_Desc']

print(crime_code_desc)
# Out:
# 4         BATTERY - SIMPLE ASSAULT
# 6         BATTERY - SIMPLE ASSAULT
# 10        BATTERY - SIMPLE ASSAULT
# 11        BATTERY - SIMPLE ASSAULT
# 13        BATTERY - SIMPLE ASSAULT
#                     ...
# 247661    BATTERY - SIMPLE ASSAULT
# 247662    BATTERY - SIMPLE ASSAULT
# 247665    BATTERY - SIMPLE ASSAULT
# 247666    BATTERY - SIMPLE ASSAULT
# 247682    BATTERY - SIMPLE ASSAULT
# Name: Crime_Code_Desc, Length: 55590, dtype: object

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/58/chlpf3nd1_l54ygz5xn6hk_00000gn/T/ipykernel_8306/2606789255.py in ?()
# ----> 1 concatenated_df.colums.tolist()
#
# ~/anaconda3/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'colums'

# %%
concatenated_df.columns.tolist()
# Out:
# ['Record_Number',
#  'Reported_Crime_Date',
#  'Actual_Crime_Date',
#  'Actual_Crime_Time',
#  'AREA ',
#  'Area_Name',
#  'Reported_District_Number',
#  'Part 1-2',
#  'Crime_Code',
#  'Crime_Code_Desc',
#  'Victim_Age',
#  'Victim_Sex',
#  'Victim_Cultural_Group',
#  'Premis_Code',
#  'Premis_Desc',
#  'Weapon_Used_Code',
#  'Weapon_Desc',
#  'File_Status',
#  'File_Status_Desc',
#  'Crime_Code_1',
#  'Crime_Location',
#  'Latitude',
#  'Longitude',
#  'Area']
